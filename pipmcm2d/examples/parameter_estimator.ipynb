# %% [markdown]
# # Example Estimating Parameters

# %%
from pipmcm2d import estimate_parameters_filepath

# %% [markdown]
# A simple function to print parameters estimates:

# %%
def estimer_parametres(csv_filepath):
    print(f"Analyse du fichier : {csv_filepath}")
    insp_param, comp_param = estimate_parameters_filepath(csv_filepath)
    mu_est, sigma_est = insp_param
    eta_est, beta_est = comp_param

    print("\n--- 1. PARAMÈTRES D'INSPECTION (Loi Normale) ---")
    print(f"Mu (Moyenne)      : {mu_est:.2f} heures")
    print(f"Sigma (Écart-type): {sigma_est:.2f} heures")


    print("\n--- 2. PARAMÈTRES DE PANNE (Loi de Weibull) ---")
    print(f"Eta (Échelle) : {eta_est:.2f} heures")
    print(f"Beta (Forme)  : {beta_est:.2f}")

# %%
# --- EXÉCUTION DU SCRIPT ---
fichier_csv = "../../simmcm2d/examples/sample_system_dataset_0.csv" 
estimer_parametres(fichier_csv)
# Out:
# Analyse du fichier : ../../simmcm2d/examples/sample_system_dataset_0.csv
#
# --- 1. PARAMÈTRES D'INSPECTION (Loi Normale) ---
# Mu (Moyenne)      : 166.54 heures
# Sigma (Écart-type): 26.70 heures
#
# --- 2. PARAMÈTRES DE PANNE (Loi de Weibull) ---
# Eta (Échelle) : 720.16 heures
# Beta (Forme)  : 3.00

# %%
# --- EXÉCUTION DU SCRIPT ---
fichier_csv = "../../simmcm2d/examples/sample_system_dataset_1.csv" 
estimer_parametres(fichier_csv)
# Out:
# Analyse du fichier : ../../simmcm2d/examples/sample_system_dataset_1.csv
#
# --- 1. PARAMÈTRES D'INSPECTION (Loi Normale) ---
# Mu (Moyenne)      : 166.13 heures
# Sigma (Écart-type): 27.24 heures
#
# --- 2. PARAMÈTRES DE PANNE (Loi de Weibull) ---
# Eta (Échelle) : 721.07 heures
# Beta (Forme)  : 2.96
